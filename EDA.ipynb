# %%
from source import create_df, preprocess, distributions, pieplot
import pandas as pd
import sqlite3

# %% [markdown]
# # **EDA**

# %%
distributions()

# %% [markdown]
# - La mayoria de usuarios tienen pocas calificaciones hechas, y se observan usuarios con demasidas calificaciones. Se deciden eliminar los usuarios con mas de 1000 calificaciones. Ademas la mayoria de peliculas fueron calificadas entre 0 y 9 veces lo que sugiere una baja confiaza del promedio de calificacion de las peliculas, se considera tomar las peliculas con mas de 10 calificaciones sin embargo seria demasiada informacion perdida

# %%
pieplot()

# %%
preprocess()

# %%
pieplot()

# %%
distributions()
